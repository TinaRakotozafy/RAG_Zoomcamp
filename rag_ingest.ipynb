# %%
from ingest import load_faq_data, build_index

documents = load_faq_data()
index = build_index(documents)

# %%
from rag_helper import RAGBase
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from rag_helper import RAGBase
#
# ImportError: cannot import name 'RAGBase' from 'rag_helper' (/workspaces/RAG_Zoomcamp/rag_helper.py)

# %%
search("docker")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 search("docker")
#
# File /workspaces/RAG_Zoomcamp/rag_helper.py:14, in search(question, course)
#      11 boost_dict = {"question": 2.0, "section": 0.5}
#      12 filter_dict = {"course": course}
# ---> 14 return index.search(
#      15     question,
#      16     boost_dict=boost_dict,
#      17     filter_dict=filter_dict,
#      18     num_results=5
#      19 )
#
# NameError: name 'index' is not defined
